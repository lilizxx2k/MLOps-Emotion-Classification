# %%
import torch
import sys
from pathlib import Path

# Go up from notebooks → MLOps → project root
PROJECT_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(PROJECT_ROOT))

from MLOps.models.baseline import baseline
from MLOps.models.model_A import model_A
